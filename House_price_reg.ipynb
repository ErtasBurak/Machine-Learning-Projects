# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive/My Drive/House Prices
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/House Prices

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_train_main=pd.read_csv("./train.csv")

# %%
df_train_main
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
df_train_main.corr()["SalePrice"].sort_values()
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# Id              -0.021917
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# MoSold           0.046432
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.351799
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.477493
# GarageYrBlt      0.486362
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# ...

# %%
df_train_main.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df_train_df=pd.DataFrame(df_train_main,columns=("KitchenAbvGr",
"EnclosedPorch", 
"MSSubClass",      
"OverallCond",     
"YrSold",          
"LowQualFinSF",    
"Id",              
"MiscVal",         
"BsmtHalfBath",   
"BsmtFinSF2",      
"3SsnPorch",       
"MoSold",         
"PoolArea",        
"ScreenPorch",     
"BedroomAbvGr",    
"BsmtUnfSF",        
"BsmtFullBath",     
"LotArea",       
"HalfBath",        
"OpenPorchSF",      
"2ndFlrSF",       
"WoodDeckSF",     
"LotFrontage",      
"BsmtFinSF1",     
"Fireplaces",      
"MasVnrArea",       
"GarageYrBlt",      
"YearRemodAdd",     
"YearBuilt",        
"TotRmsAbvGrd",     
"FullBath",         
"1stFlrSF",         
"TotalBsmtSF",      
"GarageArea",       
"GarageCars",       
"GrLivArea",        
"OverallQual",      
"SalePrice"))

# %%
df_train_df
# Out:
#       KitchenAbvGr  EnclosedPorch  ...  OverallQual  SalePrice
# 0                1              0  ...            7     208500
# 1                1              0  ...            6     181500
# 2                1              0  ...            7     223500
# 3                1            272  ...            7     140000
# 4                1              0  ...            8     250000
# ...            ...            ...  ...          ...        ...
# 1455             1              0  ...            6     175000
# 1456             1              0  ...            6     210000
# 1457             1              0  ...            7     266500
# 1458             1            112  ...            5     142125
# 1459             1              0  ...            5     147500
#
# [1460 rows x 38 columns]

# %%
df_train_df.isna().sum()
# Out:
# KitchenAbvGr     0
# EnclosedPorch    0
# MSSubClass       0
# OverallCond      0
# YrSold           0
# LowQualFinSF     0
# Id               0
# MiscVal          0
# BsmtHalfBath     0
# BsmtFinSF2       0
# 3SsnPorch        0
# MoSold           0
# PoolArea         0
# ScreenPorch      0
# BedroomAbvGr     0
# BsmtUnfSF        0
# BsmtFullBath     0
# LotArea          0
# HalfBath         0
# OpenPorchSF      0
# 2ndFlrSF         0
# WoodDeckSF       0
# LotFrontage      0
# BsmtFinSF1       0
# Fireplaces       0
# MasVnrArea       0
# GarageYrBlt      0
# YearRemodAdd     0
# YearBuilt        0
# TotRmsAbvGrd     0
# FullBath         0
# 1stFlrSF         0
# TotalBsmtSF      0
# GarageArea       0
# GarageCars       0
# GrLivArea        0
# OverallQual      0
# dtype: int64

# %%
df_train_y.isna().sum()
# Out:
# 0

# %%
df_train_df["LotFrontage"].fillna(df_train_df["LotFrontage"].mean(),inplace=True)

# %%
df_train_df["GarageYrBlt"].fillna(df_train_df["GarageYrBlt"].mean(),inplace=True)

# %%
df_train_df["MasVnrArea"].fillna(df_train_df["MasVnrArea"].mean(),inplace=True)

# %%
import seaborn as sns
from sklearn.metrics import r2_score,mean_squared_error

# %%
# !pip install xgboost

# %%
import xgboost
from xgboost import XGBRegressor

# %%
df_train_y=df_train_df["SalePrice"]

# %%
df_train_df.drop(columns=["SalePrice"],inplace=True)

# %%
xgb=XGBRegressor().fit(df_train_df,df_train_y)
# Out:
# [19:08:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
randomf=RandomForestRegressor().fit(df_train_df,df_train_y)

# %%
df_test_main=pd.read_csv("./test.csv")

# %%
df_test_main
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %%
df_test_main["Id"]
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
df_test_df=pd.DataFrame(df_test_main,columns=("KitchenAbvGr",
"EnclosedPorch", 
"MSSubClass",      
"OverallCond",     
"YrSold",          
"LowQualFinSF",    
"Id",              
"MiscVal",         
"BsmtHalfBath",   
"BsmtFinSF2",      
"3SsnPorch",       
"MoSold",         
"PoolArea",        
"ScreenPorch",     
"BedroomAbvGr",    
"BsmtUnfSF",        
"BsmtFullBath",     
"LotArea",       
"HalfBath",        
"OpenPorchSF",      
"2ndFlrSF",       
"WoodDeckSF",     
"LotFrontage",      
"BsmtFinSF1",     
"Fireplaces",      
"MasVnrArea",       
"GarageYrBlt",      
"YearRemodAdd",     
"YearBuilt",        
"TotRmsAbvGrd",     
"FullBath",         
"1stFlrSF",         
"TotalBsmtSF",      
"GarageArea",       
"GarageCars",       
"GrLivArea",        
"OverallQual"      
))

# %%
df_test_df
# Out:
#       KitchenAbvGr  EnclosedPorch  ...  GrLivArea  OverallQual
# 0                1              0  ...        896            5
# 1                1              0  ...       1329            6
# 2                1              0  ...       1629            5
# 3                1              0  ...       1604            6
# 4                1              0  ...       1280            8
# ...            ...            ...  ...        ...          ...
# 1454             1              0  ...       1092            4
# 1455             1              0  ...       1092            4
# 1456             1              0  ...       1224            5
# 1457             1              0  ...        970            5
# 1458             1              0  ...       2000            7
#
# [1459 rows x 37 columns]

# %%
df_test_df.isnull().sum()
# Out:
# KitchenAbvGr     0
# EnclosedPorch    0
# MSSubClass       0
# OverallCond      0
# YrSold           0
# LowQualFinSF     0
# Id               0
# MiscVal          0
# BsmtHalfBath     0
# BsmtFinSF2       0
# 3SsnPorch        0
# MoSold           0
# PoolArea         0
# ScreenPorch      0
# BedroomAbvGr     0
# BsmtUnfSF        0
# BsmtFullBath     0
# LotArea          0
# HalfBath         0
# OpenPorchSF      0
# 2ndFlrSF         0
# WoodDeckSF       0
# LotFrontage      0
# BsmtFinSF1       0
# Fireplaces       0
# MasVnrArea       0
# GarageYrBlt      0
# YearRemodAdd     0
# YearBuilt        0
# TotRmsAbvGrd     0
# FullBath         0
# 1stFlrSF         0
# TotalBsmtSF      0
# GarageArea       0
# GarageCars       0
# GrLivArea        0
# OverallQual      0
# dtype: int64

# %%
df_test_df["BsmtHalfBath"].fillna(df_test_df["BsmtHalfBath"].mean(),inplace=True)

# %%
df_test_df["BsmtFinSF2"].fillna(df_test_df["BsmtFinSF2"].mean(),inplace=True)

# %%
df_test_df["BsmtUnfSF"].fillna(df_test_df["BsmtUnfSF"].mean(),inplace=True)

# %%
df_test_df["BsmtFullBath"].fillna(df_test_df["BsmtFullBath"].mean(),inplace=True)

# %%
df_test_df["LotFrontage"].fillna(df_test_df["LotFrontage"].mean(),inplace=True)

# %%
df_test_df["BsmtFinSF1"].fillna(df_test_df["BsmtFinSF1"].mean(),inplace=True)

# %%
df_test_df["MasVnrArea"].fillna(df_test_df["MasVnrArea"].mean(),inplace=True)

# %%
df_test_df["GarageYrBlt"].fillna(df_test_df["GarageYrBlt"].mean(),inplace=True)

# %%
df_test_df["TotalBsmtSF"].fillna(df_test_df["TotalBsmtSF"].mean(),inplace=True)

# %%
df_test_df["GarageArea"].fillna(df_test_df["GarageArea"].mean(),inplace=True)

# %%
df_test_df["GarageCars"].fillna(df_test_df["GarageCars"].mean(),inplace=True)

# %% [markdown]
# ## With XGBOOST(RMSE=0.14329)

# %%
y_pred_xgb=xgb.predict(df_test_df)

# %%
y_pred
# Out:
# array([125763.69 , 160744.17 , 177163.16 , ..., 174735.22 , 119052.305,
#        237979.45 ], dtype=float32)

# %%
submission1=pd.DataFrame({"Id":df_test_main["Id"],"SalePrice":y_pred})

# %%
submission1
# Out:
#         Id      SalePrice
# 0     1461  125763.687500
# 1     1462  160744.171875
# 2     1463  177163.156250
# 3     1464  183517.875000
# 4     1465  187548.187500
# ...    ...            ...
# 1454  2915   77430.351562
# 1455  2916   86631.460938
# 1456  2917  174735.218750
# 1457  2918  119052.304688
# 1458  2919  237979.453125
#
# [1459 rows x 2 columns]

# %%
submission1.isnull().sum()
# Out:
# Id           0
# SalePrice    0
# dtype: int64

# %%
submission1.to_csv("/gdrive/My Drive/House Prices/Submission.csv",index=False)

# %% [markdown]
# ## With Random Forrest(RMSE=0.15029)

# %%
y_pred_randomf=randomf.predict(df_test_df)

# %%
y_pred
# Out:
# array([128250.16, 154680.  , 183903.37, ..., 164059.15, 112581.  ,
#        232047.83])

# %%
submission2=pd.DataFrame({"Id":df_test_main["Id"],"SalePrice":y_pred_randomf})

# %%
submission2.isnull().sum()
# Out:
# Id           0
# SalePrice    0
# dtype: int64

# %%
submission2.to_csv("/gdrive/My Drive/House Prices/Submission_randomf.csv",index=False)
